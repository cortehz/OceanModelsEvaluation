# %%
# from dask.distributed import Client

# client = Client("tcp://10.32.0.154:42411")
# client

# %%
# %conda install -c conda-forge git+https://github.com/mathause/regionmask.git
# %conda install -c conda-forge git+https://github.com/jbusecke/cmip6_preprocessing.git
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/r1/pxkk566n7sv889xddc0x71pr0000gn/T/ipykernel_31973/107555095.py in <module>
# ----> 1 get_ipython().run_line_magic('conda', 'install -c conda-forge git+https://github.com/mathause/regionmask.git')
#       2 get_ipython().run_line_magic('conda', 'install -c conda-forge git+https://github.com/jbusecke/cmip6_preprocessing.git')
#
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# /usr/local/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.9/site-packages/IPython/core/magics/packaging.py in conda(self, line)
#      79         """
#      80         if not _is_conda_environment():
# ---> 81             raise ValueError("The python kernel does not appear to be a conda environment.  "
#      82                              "Please use ``%pip install`` instead.")
#      83
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %% [markdown]
# Lets import ocean temperature data from a variety of models to see if the masking works well.

# %%
import regionmask
import intake
import matplotlib.pyplot as plt
from cmip6_preprocessing.preprocessing import combined_preprocessing
import xarray as xr
import numpy as np
import inspect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/r1/pxkk566n7sv889xddc0x71pr0000gn/T/ipykernel_31973/4102616335.py in <module>
# ----> 1 import regionmask
#       2 import intake
#       3 import matplotlib.pyplot as plt
#       4 from cmip6_preprocessing.preprocessing import combined_preprocessing
#       5 import xarray as xr
#
# ModuleNotFoundError: No module named 'regionmask'

# %%
# import example cloud datasets
col_url = "https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json"
col = intake.open_esm_datastore(col_url)
cat = col.search(source_id=['CAMS-CSM1-0', 'CNRM-CM6-1', 'CNRM-ESM2-1', 'ACCESS-CM2', 'ACCESS-ESM1-5', 'EC-Earth3-Veg',
                            'MIROC-ES2L', 'MIROC6', 'HadGEM3-GC31-LL', 'UKESM1-0-LL', 'MPI-ESM1-2-HR', 'MRI-ESM2-0',
                            'NorCPM1', 'GFDL-CM4', 'GFDL-ESM4', 'NESM3'],
                 experiment_id='historical', variable_id='thetao')

lines = inspect.getsource(cat.to_dataset_dict)
print(lines, "lines")
data_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': "True", 'decode_times': "False"},
                                preprocess=combined_preprocessing)
# Out:
#     def to_dataset_dict(
#         self,
#         zarr_kwargs: Dict[str, Any] = None,
#         cdf_kwargs: Dict[str, Any] = None,
#         preprocess: Dict[str, Any] = None,
#         storage_options: Dict[str, Any] = None,
#         progressbar: bool = None,
#         aggregate: bool = None,
#     ) -> Dict[str, xr.Dataset]:
#         """
#         Load catalog entries into a dictionary of xarray datasets.
#
#         Parameters
#         ----------
#         zarr_kwargs : dict
#             Keyword arguments to pass to :py:func:`~xarray.open_zarr` function
#         cdf_kwargs : dict
#             Keyword arguments to pass to :py:func:`~xarray.open_dataset` function.  If specifying chunks, the chunking
#             is applied to each netcdf file.  Therefore, chunks must refer to dimensions that are present in each netcdf
#             file, or chunking will fail.
#         preprocess : callable, optional
#             If provided, call this function on each dataset prior to aggregation.
#         storage_options : dict, optional
#             Parameters passed to the backend file-system such as Google Cloud Storage,
#             Amazon Web Service S3.
#         progressbar : bool
#             If True, will print a progress bar to standard error (stderr)
#             when loading assets into :py:class:`~xarray.Dataset`.
#         aggregate : bool, optional
#             If False, no aggregation will be done.
#
#         Returns
#         -------
#         dsets : dict
#            A dictionary of xarray :py:class:`~xarray.Dataset`.
#
#         Examples
#         --------
#         >>> import intake
#         >>> col = intake.open_esm_datastore("glade-cmip6.json")
#         >>> cat = col.search(
#         ...     source_id=["BCC-CSM2-MR", "CNRM-CM6-1", "CNRM-ESM2-1"],
#         ...     experiment_id=["historical", "ssp585"],
#         ...     variable_id="pr",
#         ...     table_id="Amon",
#         ...     grid_label="gn",
#         ... )
#         >>> dsets = cat.to_dataset_dict()
#         >>> dsets.keys()
#         dict_keys(['CMIP.BCC.BCC-CSM2-MR.historical.Amon.gn', 'ScenarioMIP.BCC.BCC-CSM2-MR.ssp585.Amon.gn'])
#         >>> dsets["CMIP.BCC.BCC-CSM2-MR.historical.Amon.gn"]
#         <xarray.Dataset>
#         Dimensions:    (bnds: 2, lat: 160, lon: 320, member_id: 3, time: 1980)
#         Coordinates:
#         * lon        (lon) float64 0.0 1.125 2.25 3.375 ... 355.5 356.6 357.8 358.9
#         * lat        (lat) float64 -89.14 -88.03 -86.91 -85.79 ... 86.91 88.03 89.14
#         * time       (time) object 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#         * member_id  (member_id) <U8 'r1i1p1f1' 'r2i1p1f1' 'r3i1p1f1'
#         Dimensions without coordinates: bnds
#         Data variables:
#             lat_bnds   (lat, bnds) float64 dask.array<chunksize=(160, 2), meta=np.ndarray>
#             lon_bnds   (lon, bnds) float64 dask.array<chunksize=(320, 2), meta=np.ndarray>
#             time_bnds  (time, bnds) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
#             pr         (member_id, time, lat, lon) float32 dask.array<chunksize=(1, 600, 160, 320), meta=np.ndarray>
#         """
#
#         # Return fast
#         if not self.keys():
#             warn('There are no datasets to load! Returning an empty dictionary.')
#             return {}
#
#         source_kwargs = OrderedDict(
#             zarr_kwargs=zarr_kwargs,
#             cdf_kwargs=cdf_kwargs,
#             preprocess=preprocess,
#             storage_options=storage_options,
#         )
#
#         if progressbar is not None:
#             self.progressbar = progressbar
#
#         if preprocess is not None and not callable(preprocess):
#             raise ValueError('preprocess argument must be callable')
#
#         if aggregate is not None and not aggregate:
#             self = deepcopy(self)
#             self.groupby_attrs = []
#
#         if self.progressbar:
#             print(
#                 f"""\n--> The keys in the returned dictionary of datasets are constructed as follows:\n\t'{self.key_template}'"""
#             )
#
#         def _load_source(key, source):
#             return key, source.to_dask()
#
#         sources = {key: source(**source_kwargs) for key, source in self.items()}
#         progress, total = None, None
#         if self.progressbar:
#             total = len(sources)
#             progress = progress_bar(range(total))
#
#         self._datasets = {}
#         with concurrent.futures.ThreadPoolExecutor(max_workers=dask.system.CPU_COUNT) as executor:
#             future_tasks = [
#                 executor.submit(_load_source, key, source) for key, source in sources.items()
#             ]
#             for i, task in enumerate(concurrent.futures.as_completed(future_tasks)):
#                 key, ds = task.result()
#                 self._datasets[key] = ds
#                 if self.progressbar:
#                     progress.update(i)
#             if self.progressbar:
#                 progress.update(total)
#             return self._datasets
#  lines
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='23' class='' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [23/23 01:26<00:00]
#     </div>
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:310: UserWarning: Found time as dimension in `lon_bounds`. Assuming this is an error and just picking the first step along that dimension.
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r4i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r35i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r37i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r36i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r26i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r15i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r44i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r16i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r47i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r17i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r12i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r11i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r48i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r27i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r21i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r18i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r46i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r4i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r50i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r5i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r6i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r34i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r7i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r32i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r22i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r8i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r42i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r13i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r10i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:310: UserWarning: Found time as dimension in `lon_bounds`. Assuming this is an error and just picking the first step along that dimension.
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r1i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r38i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r6i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r24i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r49i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r19i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r7i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r9i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r45i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r29i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r5i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r43i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r30i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r31i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r6i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r8i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r9i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r5i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r39i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r23i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r8i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r33i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r28i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r9i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r41i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r14i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r25i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r40i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r4i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r20i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r7i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r3i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC6.historical.r2i1p1f1.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.Omon.gr1.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /Users/enyi/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/enyi/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/enyi/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/enyi/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/enyi/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/enyi/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %% [markdown]
# First we need to load the natural earth ocean basins.

# %%
# load ocean basin data
# basins = regionmask.defined_regions.natural_earth.ocean_basins_50

basins = regionmask.defined_regions.natural_earth_v4_1_0.ocean_basins_50
basins.plot(add_ocean=False, add_label=False)
# Out:
# <GeoAxesSubplot:>

# %%
from cmip6_preprocessing.regionmask import merged_mask

# %% [markdown]
# When using the defaults this will index the North and South Pacific with numeric values of 2 and 3 respectively. The Maritime Continent gets a separate index (4). We will now load example data from many CMIP6 models, create the mask, and select only the points with values 2,3, and 4.

# %%
# loop over models and mask out the pacific
import cartopy.crs as ccrs

for k, ds in data_dict.items():
    if 'lev' in ds.dims:
        model = ds.attrs['source_id']
        if 'member_id' in ds.dims:
            ds = ds.isel(member_id=0)
        ds = ds.thetao.isel(time=0, lev=0).squeeze()
        # print(basins["Arctic Ocean"], "basins")

        # basins["Ross Sea Eastern Basin"].drop

        # lines = inspect.getsource(merged_mask)
        # print(lines, "lines")

        # if basins != "Ross Sea Eastern Basin"
        mask = merged_mask(basins,ds)

     

        

        kwargs = dict(x='lon', y='lat',transform = ccrs.PlateCarree(), infer_intervals=False)
        fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=[20,2], subplot_kw={'projection':ccrs.Robinson(190)})
        ds.plot(ax=ax1, **kwargs)
        ax1.set_title(f"Raw field {model}")
        
        ds_masked = ds.where(np.logical_or(np.logical_or(mask == 2, mask==3),mask==4)) # Pacific + Maritime Continent
        ds_masked.plot(ax=ax2, **kwargs)
        ax2.set_title(f"Masked Pacific {model}")
        mask.plot(ax=ax3, cmap='tab20', vmin=0, vmax=19, **kwargs)
        ax3.set_title(f"Full Mask {model}")
        for ax in [ax1, ax2, ax3]:
            ax.coastlines()
